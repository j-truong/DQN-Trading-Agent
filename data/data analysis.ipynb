# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### EUR GBP

# %%
df = pd.read_excel('eur-gbp.xlsx', names=['date','open','high','low','close','volume'])
df.head()
# Out:
#                  date     open     high      low    close  volume
# 0 2018-01-01 17:02:00  0.88800  0.88800  0.88800  0.88800       0
# 1 2018-01-01 17:03:00  0.88806  0.88806  0.88806  0.88806       0
# 2 2018-01-01 17:04:00  0.88806  0.88806  0.88806  0.88806       0
# 3 2018-01-01 17:05:00  0.88818  0.88818  0.88818  0.88818       0
# 4 2018-01-01 17:06:00  0.88812  0.88812  0.88812  0.88812       0

# %%
plt.figure(figsize=(15,8))
plt.plot(range(len(df)), df.iloc[:,4])

# %% [markdown]
# 1 year one minute: 369383rows
# ep_size: 120, train_eps: 763
# ts: 121589, time: 1 day
# ep_size: 120, train_eps: 500
# ts: 60000, time: 15 hours
#
#
# entire dataset: 4 months (end of April) (1 day to compute)
# last ts: 121589
#
# training set: start til last 2 weeks of Feb
# last ts: 46339
# episodes = 386
#
# validation set: end of Feb (12 hours)
# last ts: 60680

# %% [markdown]
# ### EUR USD

# %%
df = pd.read_excel('eur-usd2017.xlsx', names=['date','open','high','low','close','volume'])
df.head()
# Out:
#                  date     open     high      low    close  volume
# 0 2017-01-02 02:01:00  1.05209  1.05209  1.05177  1.05179       0
# 1 2017-01-02 02:02:00  1.05177  1.05198  1.05177  1.05178       0
# 2 2017-01-02 02:03:00  1.05188  1.05200  1.05188  1.05200       0
# 3 2017-01-02 02:04:00  1.05196  1.05204  1.05196  1.05203       0
# 4 2017-01-02 02:06:00  1.05196  1.05204  1.05196  1.05204       0

# %%
plt.figure(figsize=(15,8))
plt.plot(range(len(df)), df.iloc[:,4])

# %% [markdown]
# ### EUR-CHF

# %%
df = pd.read_excel('eur-usd2017.xlsx', names=['date','open','high','low','close','volume'])
df.head()
# Out:
#                  date     open     high      low    close  volume
# 0 2017-01-02 02:01:00  1.05209  1.05209  1.05177  1.05179       0
# 1 2017-01-02 02:02:00  1.05177  1.05198  1.05177  1.05178       0
# 2 2017-01-02 02:03:00  1.05188  1.05200  1.05188  1.05200       0
# 3 2017-01-02 02:04:00  1.05196  1.05204  1.05196  1.05203       0
# 4 2017-01-02 02:06:00  1.05196  1.05204  1.05196  1.05204       0

# %%
plt.figure(figsize=(15,8))
plt.plot(range(len(df)), df.iloc[:,4])
