# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import pickle
from matplotlib.ticker import MultipleLocator

# %%
fname = "force_explore.pickle"
with open(fname, 'rb') as handle:
    explore = pickle.load(handle)
    
fname = "unforce_explore.pickle"
with open(fname, 'rb') as handle:
    unexplore = pickle.load(handle)

# %%
explore.head()
# Out:
#      price   reward   inv  portfolio  episode  action       bank   ts
# 0  0.88773  0.00000  47.0  200.00000      0.0   -47.0  158.27669  0.0
# 1  0.88788  0.00165  36.0  200.00705      0.0    11.0  168.04337  1.0
# 2  0.88765  0.00000  97.0  199.99877      0.0   -61.0  113.89672  2.0
# 3  0.88799  0.01514  44.0  200.03175      0.0    53.0  160.96019  3.0
# 4  0.88763  0.00000   3.0  200.01591      0.0    41.0  197.35302  4.0

# %%
val_explore = explore[explore.episode==-1]
val_unexplore = unexplore[unexplore.episode==-1]

val_l = len(val_explore)

plt.plot(range(val_l), val_explore.portfolio, label='explore')
plt.plot(range(val_l), val_unexplore.portfolio, label='unexplore')

#factor = val_explore.portfolio[83167] / val_explore.price[83167]
#plt.plot(range(val_l), factor*val_explore.price, label='buy and hold')

plt.title('validation portfolio')
plt.xlabel('timestep')
plt.ylabel('portfolio')
plt.legend()

# %%
val_explore.price.iloc[0]
# Out:
# 0.88915

# %%
val_explore
# Out:
#          price  reward   inv  portfolio  episode  action       bank       ts
# 42074  0.88915     0.0   0.0  200.00000     -1.0     0.0  200.00000  46340.0
# 42075  0.88923     0.0   0.0  200.00000     -1.0     0.0  200.00000  46341.0
# 42076  0.88925     0.0  43.0  200.00000     -1.0   -43.0  161.76225  46342.0
# 42077  0.88926     0.0  43.0  200.00043     -1.0     0.0  161.76225  46343.0
# 42078  0.88923     0.0  43.0  199.99914     -1.0     0.0  161.76225  46344.0
# ...        ...     ...   ...        ...      ...     ...        ...      ...
# 56409  0.88669     0.0   5.0  200.16237     -1.0     0.0  195.72892  60675.0
# 56410  0.88672     0.0   5.0  200.16252     -1.0     0.0  195.72892  60676.0
# 56411  0.88670     0.0  18.0  200.16242     -1.0   -13.0  184.20182  60677.0
# 56412  0.88666     0.0  18.0  200.16170     -1.0     0.0  184.20182  60678.0
# 56413  0.88675     0.0  18.0  200.16332     -1.0     0.0  184.20182  60679.0
#
# [14340 rows x 8 columns]

# %%
fname = "test.pickle"
with open(fname, 'rb') as handle:
    test = pickle.load(handle)

# %%
test
# Out:
#        inv       ts   reward    price  percent  episode  action        bank  \
# 0     45.0      0.0  0.00000  0.88773    0.005      0.0   -45.0  159.852411
# 1     33.0      1.0  0.00180  0.88788    0.005      0.0    12.0  170.453698
# 2     33.0      2.0  0.00000  0.88765    0.005      0.0     0.0  170.453698
# 3     75.0      3.0  0.00000  0.88799    0.005      0.0   -42.0  132.971640
# 4    134.0      4.0  0.00000  0.88763    0.005      0.0   -59.0   80.339619
# ..     ...      ...      ...      ...      ...      ...     ...         ...
# 331  126.0    107.0  0.00000  0.88884    0.050      0.0     0.0   63.747443
# 332  114.0    108.0  0.00144  0.88885    0.050      0.0    12.0   73.880333
# 333    0.0  91632.0  0.00000  0.87793    0.050     -1.0     0.0  200.000000
# 334    0.0  91633.0  0.00000  0.87792    0.050     -1.0     0.0  200.000000
# 335    0.0  91634.0  0.00000  0.87785    0.050     -1.0     0.0  200.000000
#
#       portfolio
# 0    199.800261
# 1    199.753738
# 2    199.746148
# 3    199.570890
# 4    199.282039
# ..          ...
# 331  175.741283
# 332  175.209233
# 333  200.000000
# 334  200.000000
# 335  200.000000
#
# [336 rows x 9 columns]
